# %%
# %pip install pandas pymongo
# Out:
# Requirement already satisfied: pandas in c:\users\meet dhote\anaconda3\lib\site-packages (1.4.2)
# Collecting pymongo
#   Downloading pymongo-4.6.1-cp39-cp39-win_amd64.whl (472 kB)
# Requirement already satisfied: pytz>=2020.1 in c:\users\meet dhote\anaconda3\lib\site-packages (from pandas) (2021.3)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\meet dhote\anaconda3\lib\site-packages (from pandas) (1.21.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\meet dhote\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Collecting dnspython<3.0.0,>=1.16.0
#   Downloading dnspython-2.4.2-py3-none-any.whl (300 kB)
# Requirement already satisfied: six>=1.5 in c:\users\meet dhote\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.4.2 pymongo-4.6.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from pymongo import MongoClient
#mongodb atlas
connection_string = "mongodb+srv://meetdhote10:kix1nmG55O5RdkDv@cluster0.0adtonn.mongodb.net/?retryWrites=true&w=majority"

client = MongoClient(connection_string)

db = client.get_database("student")
collection = db["collection"]

# %%
import pandas as pd
data = pd.read_csv("C:\\Users\\Meet Dhote\\Desktop\\BDT Project\\dataset.csv")
data
# Out:
#                 Course  Age at enrollment  Daytime/evening attendance  \
# 0              Physics                 16                           1
# 1            Sociology                 10                           1
# 2              English                 12                           1
# 3                Music                 14                           1
# 4            Chemistry                 11                           0
# ...                ...                ...                         ...
# 4421        Psychology                 13                           1
# 4422         Economics                 15                           1
# 4423             Music                 11                           1
# 4424             Maths                 14                           0
# 4425  Foreign Language                 16                           0
#
#                Area       Caste  Displaced  Educational special needs  Debtor  \
# 0            Sikkim      Slaute          1                          0       0
# 1         Rajasthan     Ambacam          1                          0       0
# 2       Uttaranchal     Chawhan          1                          0       0
# 3     Uttar Pradesh      Rajput          1                          0       0
# 4         Rajasthan  Raghuransi          0                          0       0
# ...             ...         ...        ...                        ...     ...
# 4421    Uttaranchal       Asooy          1                          0       0
# 4422        Haryana  Raghuransi          1                          0       0
# 4423          Delhi       Marer          1                          0       0
# 4424            Goa     Kanojia          0                          1       1
# 4425          Bihar      Rajput          1                          1       1
#
#       Tuition fees up to date  Gender  Scholarship holder  \
# 0                           1    Male                   0
# 1                           0    Male                   0
# 2                           0    Male                   0
# 3                           1  Female                   0
# 4                           1  Female                   0
# ...                       ...     ...                 ...
# 4421                        1  Female                   1
# 4422                        1  Female                   1
# 4423                        1  Female                   0
# 4424                        0  Female                   1
# 4425                        1  Female                   1
#
#       Curricular units 1st sem (grade)  Curricular units 2nd sem (grade)  \
# 0                             0.000000                          0.000000
# 1                            14.000000                         13.666667
# 2                             0.000000                          0.000000
# 3                            13.428571                         12.400000
# 4                            12.333333                         13.000000
# ...                                ...                               ...
# 4421                         14.912500                         13.500000
# 4422                         13.800000                         12.000000
# 4423                         11.666667                         13.000000
# 4424                         11.000000                         10.000000
# 4425                         12.600000                         11.250000
#
#       Unemployment rate  Inflation rate   GDP    Target  \
# 0                  10.8             1.4  1.74   Dropout
# 1                  13.9            -0.3  0.79  Graduate
# 2                  10.8             1.4  1.74   Dropout
# 3                   9.4            -0.8 -3.12  Graduate
# 4                  13.9            -0.3  0.79  Graduate
# ...                 ...             ...   ...       ...
# 4421               13.9            -0.3  0.79   Dropout
# 4422                9.4            -0.8 -3.12  Graduate
# 4423               12.7             3.7 -1.70  Graduate
# 4424               10.8             1.4  0.79   Dropout
# 4425               15.5             2.6 -3.12  Graduate
#
#       Previous Qualification
# 0                          8
# 1                          6
# 2                          8
# 3                          6
# 4                          9
# ...                      ...
# 4421                       6
# 4422                       6
# 4423                       7
# 4424                       9
# 4425                       9
#
# [4426 rows x 18 columns]

# %%
print(data.dtypes)
# Out:
# Course                               object
# Age at enrollment                     int64
# Daytime/evening attendance            int64
# Area                                 object
# Caste                                object
# Displaced                             int64
# Educational special needs             int64
# Debtor                                int64
# Tuition fees up to date               int64
# Gender                               object
# Scholarship holder                    int64
# Curricular units 1st sem (grade)    float64
# Curricular units 2nd sem (grade)    float64
# Unemployment rate                   float64
# Inflation rate                      float64
# GDP                                 float64
# Target                               object
# Previous Qualification                int64
# dtype: object

# %%
# Convert DataFrame to list of dictionaries
data_dict = data.to_dict(orient='records')

# Insert data into MongoDB
collection.insert_many(data_dict)
# Out:
# InsertManyResult([ObjectId('656877090deaa7bf7bcde971'), ObjectId('656877090deaa7bf7bcde972'), ObjectId('656877090deaa7bf7bcde973'), ObjectId('656877090deaa7bf7bcde974'), ObjectId('656877090deaa7bf7bcde975'), ObjectId('656877090deaa7bf7bcde976'), ObjectId('656877090deaa7bf7bcde977'), ObjectId('656877090deaa7bf7bcde978'), ObjectId('656877090deaa7bf7bcde979'), ObjectId('656877090deaa7bf7bcde97a'), ObjectId('656877090deaa7bf7bcde97b'), ObjectId('656877090deaa7bf7bcde97c'), ObjectId('656877090deaa7bf7bcde97d'), ObjectId('656877090deaa7bf7bcde97e'), ObjectId('656877090deaa7bf7bcde97f'), ObjectId('656877090deaa7bf7bcde980'), ObjectId('656877090deaa7bf7bcde981'), ObjectId('656877090deaa7bf7bcde982'), ObjectId('656877090deaa7bf7bcde983'), ObjectId('656877090deaa7bf7bcde984'), ObjectId('656877090deaa7bf7bcde985'), ObjectId('656877090deaa7bf7bcde986'), ObjectId('656877090deaa7bf7bcde987'), ObjectId('656877090deaa7bf7bcde988'), ObjectId('656877090deaa7bf7bcde989'), ObjectId('656877090deaa7bf7bcde98a'), ObjectId('656877090deaa7bf7bcde98b'), ObjectId('656877090deaa7bf7bcde98c'), ObjectId('656877090deaa7bf7bcde98d'), ObjectId('656877090deaa7bf7bcde98e'), ObjectId('656877090deaa7bf7bcde98f'), ObjectId('656877090deaa7bf7bcde990'), ObjectId('656877090deaa7bf7bcde991'), ObjectId('656877090deaa7bf7bcde992'), ObjectId('656877090deaa7bf7bcde993'), ObjectId('656877090deaa7bf7bcde994'), ObjectId('656877090deaa7bf7bcde995'), ObjectId('656877090deaa7bf7bcde996'), ObjectId('656877090deaa7bf7bcde997'), ObjectId('656877090deaa7bf7bcde998'), ObjectId('656877090deaa7bf7bcde999'), ObjectId('656877090deaa7bf7bcde99a'), ObjectId('656877090deaa7bf7bcde99b'), ObjectId('656877090deaa7bf7bcde99c'), ObjectId('656877090deaa7bf7bcde99d'), ObjectId('656877090deaa7bf7bcde99e'), ObjectId('656877090deaa7bf7bcde99f'), ObjectId('656877090deaa7bf7bcde9a0'), ObjectId('656877090deaa7bf7bcde9a1'), ObjectId('656877090deaa7bf7bcde9a2'), ObjectId('656877090deaa7bf7bcde9a3'), ObjectId('656877090deaa7bf7bcde9a4'), ObjectId('656877090deaa7bf7bcde9a5'), ObjectId('656877090deaa7bf7bcde9a6'), ObjectId('656877090deaa7bf7bcde9a7'), ObjectId('656877090deaa7bf7bcde9a8'), ObjectId('656877090deaa7bf7bcde9a9'), ObjectId('656877090deaa7bf7bcde9aa'), ObjectId('656877090deaa7bf7bcde9ab'), ObjectId('656877090deaa7bf7bcde9ac'), ObjectId('656877090deaa7bf7bcde9ad'), ObjectId('656877090deaa7bf7bcde9ae'), ObjectId('656877090deaa7bf7bcde9af'), ObjectId('656877090deaa7bf7bcde9b0'), ObjectId('656877090deaa7bf7bcde9b1'), ObjectId('656877090deaa7bf7bcde9b2'), ObjectId('656877090deaa7bf7bcde9b3'), ObjectId('656877090deaa7bf7bcde9b4'), ObjectId('656877090deaa7bf7bcde9b5'), ObjectId('656877090deaa7bf7bcde9b6'), ObjectId('656877090deaa7bf7bcde9b7'), ObjectId('656877090deaa7bf7bcde9b8'), ObjectId('656877090deaa7bf7bcde9b9'), ObjectId('656877090deaa7bf7bcde9ba'), ObjectId('656877090deaa7bf7bcde9bb'), ObjectId('656877090deaa7bf7bcde9bc'), ObjectId('656877090deaa7bf7bcde9bd'), ObjectId('656877090deaa7bf7bcde9be'), ObjectId('656877090deaa7bf7bcde9bf'), ObjectId('656877090deaa7bf7bcde9c0'), ObjectId('656877090deaa7bf7bcde9c1'), ObjectId('656877090deaa7bf7bcde9c2'), ObjectId('656877090deaa7bf7bcde9c3'), ObjectId('656877090deaa7bf7bcde9c4'), ObjectId('656877090deaa7bf7bcde9c5'), ObjectId('656877090deaa7bf7bcde9c6'), ObjectId('656877090deaa7bf7bcde9c7'), ObjectId('656877090deaa7bf7bcde9c8'), ObjectId('656877090deaa7bf7bcde9c9'), ObjectId('656877090deaa7bf7bcde9ca'), ObjectId('656877090deaa7bf7bcde9cb'), ObjectId('656877090deaa7bf7bcde9cc'), ObjectId('656877090deaa7bf7bcde9cd'), ObjectId('656877090deaa7bf7bcde9ce'), ObjectId('656877090deaa7bf7bcde9cf'), ObjectId('656877090deaa7bf7bcde9d0'), ObjectId('656877090deaa7bf7bcde9d1'), ObjectId('656877090deaa7bf7bcde9d2'), ObjectId('656877090deaa7bf7bcde9d3'), ObjectId('656877090deaa7bf7bcde9d4'), ObjectId('656877090deaa7bf7bcde9d5'), ObjectId('656877090deaa7bf7bcde9d6'), ObjectId('656877090deaa7bf7bcde9d7'), ObjectId('656877090deaa7bf7bcde9d8'), ObjectId('656877090deaa7bf7bcd ...

# %% [markdown]
# Data Preprocessing

# %%
collection.update_many({}, {"$rename": {"Age at enrollment": "Age"}})
# Out:
# UpdateResult({'n': 4426, 'electionId': ObjectId('7fffffff0000000000000005'), 'opTime': {'ts': Timestamp(1701345129, 4435), 't': 5}, 'nModified': 4426, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1701345129, 4435), 'signature': {'hash': b'\x0c?\xd2\n\x80\xe8B\x8a\x04\xf2\xbeRU\x03\xd8\x1a\n\xae\xdd\xda', 'keyId': 7306486278193676293}}, 'operationTime': Timestamp(1701345129, 4435), 'updatedExisting': True}, acknowledged=True)

# %%
collection.update_many({}, {"$unset": {"Educational special needs": "", "Unemployment rate": "", "Inflation rate": ""}})
# Out:
# UpdateResult({'n': 4426, 'electionId': ObjectId('7fffffff0000000000000005'), 'opTime': {'ts': Timestamp(1701345138, 4436), 't': 5}, 'nModified': 4426, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1701345138, 4436), 'signature': {'hash': b'sm\xd2\xd0\x7f\xe7\xc7j\x03\n\x18\x11w\x14\xd4\x90\xb0\xa5\xdb\x05', 'keyId': 7306486278193676293}}, 'operationTime': Timestamp(1701345138, 4436), 'updatedExisting': True}, acknowledged=True)

# %%
null_documents = collection.find({"field_name": {"$exists": False}})

# %%
distinct_targets = collection.distinct("Target")
print(distinct_targets)
# Out:
# ['Dropout', 'Enrolled', 'Graduate']

# %%
target_counts_pipeline = [
    {"$group": {"_id": "$Target", "count": {"$sum": 1}}}
]
target_counts = list(collection.aggregate(target_counts_pipeline))
print(target_counts)
# Out:
# [{'_id': 'Dropout', 'count': 1422}, {'_id': 'Graduate', 'count': 2210}, {'_id': 'Enrolled', 'count': 794}]
